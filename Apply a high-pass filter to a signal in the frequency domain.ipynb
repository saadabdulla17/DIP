# %%
import numpy as np
import matplotlib.pyplot as plt

signal = np.array([1, 2, 3, 4, 5])
fft_result = np.fft.fft(signal)

cutoff_frequency = 0.5
fft_result[np.abs(fft_result) < cutoff_frequency * np.max(np.abs(fft_result))] = 0

filtered_signal = np.fft.ifft(fft_result)

plt.plot(signal, label='Original Signal')
plt.plot(filtered_signal, label='Filtered Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('High-Pass Filter')
plt.legend()
plt.show()
# Out:
# /lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
