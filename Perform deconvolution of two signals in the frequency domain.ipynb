# %%
import numpy as np
import matplotlib.pyplot as plt

signal1 = np.array([1, 2, 3, 4, 5])
signal2 = np.array([1, -1, 1, -1, 1])

fft_signal1 = np.fft.fft(signal1)
fft_signal2 = np.fft.fft(signal2)
deconvolved_signal = np.fft.ifft(fft_signal1 / fft_signal2)

plt.plot(deconvolved_signal)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Deconvolution')
plt.show()
# Out:
# /lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
