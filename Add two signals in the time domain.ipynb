# %%
import numpy as np
import matplotlib.pyplot as plt

signal1 = np.array([1, 2, 3, 4, 5])
signal2 = np.array([1, -1, 1, -1, 1])
added_signal = signal1 + signal2

plt.plot(added_signal)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Signal Addition')
plt.show()
