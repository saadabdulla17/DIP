# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.linspace(-1, 1, 1000)
sigma = 0.1
gaussian_pulse = np.exp(-time**2 / (2 * sigma**2))

plt.plot(time, gaussian_pulse)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Gaussian Pulse (Time Domain)')
plt.show()
